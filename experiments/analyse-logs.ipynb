# %%
import re
import urllib.parse
import pandas as pd
import time
from SPARQLWrapper import SPARQLWrapper, JSON
from IPython.display import display
from itables import show
from tqdm import tqdm

# %%
logFile = '../logs/sniffer.txt'
endpoint = "http://localhost:8887/blazegraph/sparql"

# %%
with open(logFile, 'r') as f:
    logRaw = f.read()

# %%
logCleaned = re.sub(r'\n\nT.(\d{1,3}\.){3}\d{1,3}:\d{1,5}.*\n','',logRaw)

# %%
queryPattern = r'query=\S*'

# %%
queriesRaw = re.findall(queryPattern, logCleaned)

# %%
print("Found %d queries" % len(queriesRaw))
# Out:
# Found 1016 queries

# %%
queries = []
for query in queriesRaw:
    query = query[len("query="):]
    query = urllib.parse.unquote_plus(query)
    query = query.replace("\n", "")
    if query[-3:] == 'GET':
        query = query[:-3]
    if query[-4:] == 'POST':
        query = query[:-4]
    if query[-8:] == 'HTTP/1.1':
        query = query[:-8]
    queries.append(query)

# %%
sparql = SPARQLWrapper(endpoint)
sparql.method = "POST"
sparql.setReturnFormat(JSON)

# %%
analysis = []
for query in tqdm(queries):
    sparql.setQuery(query)
    try:
        start = time.perf_counter()
        ret = sparql.queryAndConvert()
        responseTime = time.perf_counter() - start
    except Exception as e:
        print("Query:", query)
        print("Error:", e)
        ret = False
    if ret:
        analysis.append({
            "query": query,
            "return": ret,
            "responseTime": responseTime
        })
# Out:
# 100%|██████████| 1016/1016 [01:37<00:00, 10.45it/s]

# %%
table = [{
    "index": i,
    "query": d['query'],
    "responseTime": d['responseTime'],
    "numVars": len(d['return']['head']['vars']) if not 'boolean' in d['return'] else 'boolean',
    "numResults": len(d['return']['results']['bindings']) if not 'boolean' in d['return'] else 'boolean'
} for i, d in enumerate(analysis)]
df = pd.DataFrame(table)

# %%
show(df)
# Out:
# <div><table id="e8a86956-9f5f-45e6-87a5-8dff44f0aa38" class="display"><thead>
#     <tr style="text-align: right;">
#
#       <th>index</th>
#       <th>numResults</th>
#       <th>numVars</th>
#       <th>query</th>
#       <th>responseTime</th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         var dt_args = {"columnDefs": [{"width": "70px", "targets": "_all"}], "data": [[0, "2", "8", "SELECT ?subject ?p0 ?p1 ?p2 ?p3 ?p4 ?p5 ?p6 WHERE {{{ \t?subject <http://www.w3.org/2004/02/skos/core#prefLabel> ?p0 .  }VALUES (?subject) { (<https://resource.swissartresearch.net/artwork/zbz-990101844300205508>) }}UNION{{ \t?subject <http://www.w3.org/2000/01/rdf-schema#label> ?p1 .  }VALUES (?subject) { (<https://resource.swissartresearch.net/artwork/zbz-990101844300205508>) }}UNION{{ \t?subject <https://d-nb.info/standards/elementset/gnd#preferredName> ?p2 .  }VALUES (?subject) { (<https://resource.swissartresearch.net/artwork/zbz-990101844300205508>) }}UNION{{ \t?subject <http://www.cidoc-crm.org/cidoc-crm/P1_is_identified_by> ?p3 .  }VALUES (?subject) { (<https://resource.swissartresearch.net/artwork/zbz-990101844300205508>) }}UNION{{ \t?subject <http://www.researchspace.org/ontology/displayLabel> ?p4 .  }VALUES (?subject) { (<https://resource.swissartresearch.net/artwork/zbz-990101844300205508>) }}UNION{{ \t?subject <http://www.cidoc-crm.org/cidoc-crm/P82_at_some_time_within> ?p5 .  }VALUES (?subject) { (<https://resource.swissartresearch.net/artwork/zbz-990101844300205508>) }}UNION{{ \t?subject <https://d-nb.info/standards/elementset/gnd#preferredNameForTheSubjectHeading> ?p6 .  }VALUES (?subject) { (<https://resource.swissartresearch.net/artwork/zbz-990101844300205508>) }}} ", 0.02219], [1, "boolean", "boolean", "ASK { { <https://resource.swissartresearch.net/artwork/zbz-990101844300205508> ?p ?o } UNION { ?s <https://resource.swissartresearch.net/artwork/zbz-990101844300205508> ?o} UNION {?s ?p <https://resource.swissartresearch.net/artwork/zbz-990101844300205508>} }", 0.007883], [2, "14", "1", "PREFIX : <http://www.metaphacts.com/resource/>PREFIX schema: <http://schema.org/>PREFIX gndo: <https://d-nb.info/standards/elementset/gnd#>PREFIX User: <http://www.metaphacts.com/resource/user/>PREFIX Help: <http://help.metaphacts.com/resource/>PREFIX Platform: <http://www.metaphacts.com/ontologies/platform#>PREFIX owl: <http://www.w3.org/2002/07/owl#>PREFIX wdt: <http://www.wikidata.org/prop/direct/>PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>PREFIX skos: <http://www.w3.org/2004/02/skos/core#>PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>PREFIX type: <https://resource.swissartresearch.net/type/>PREFIX crmdig: <http://www.ics.forth.gr/isl/CRMdig/>PREFIX wd: <http://www.wikidata.org/entity/>PREFIX rso: <http://www.researchspace.org/ontology/>PREFIX crmsci: <http://www.cidoc-crm.org/cidoc-crm/CRMsci/>PREFIX search: <https://platform.swissartresearch.net/search/>PREFIX oa: <http://www.w3.org/ns/oa#>PREFIX sh: <http://www.w3.org/ns/shacl#>PREFIX aat: <http://vocab.getty.edu/aat/>PREFIX Assets: <http://www.metaphacts.com/resource/assets/>PREFIX dcterms: <http://purl.org/dc/terms/>PREFIX place: <https://resource.swissartresearch.net/place/>PREFIX sp: <http://spinrdf.org/sp#>PREFIX prov: <http://www.w3.org/ns/prov#>PREFIX smapshotapi: <https://smapshot.heig-vd.ch/api/v1/>PREFIX iqvoc: <https://iqvoc.swissartresearch.net/>PREFIX queryPartial: <https://static.swissartresearch.net/queryPartial/>PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>PREFIX query: <https://static.swissartresearch.net/query/>PREFIX Service: <http://www.metaphacts.com/ontologies/platform/service/>PREFIX crminf: <http://www.ics.forth.gr/isl/CRMinf/>PREFIX artwork: <https://resource.swissartresearch.net/artwork/>PREFIX Admin: <http://www.metaphacts.com/resource/admin/>PREFIX Default: <https://static.swissartresearch.net/page/>PREFIX sari: <https://platform.swissartresearch.net/>PREFIX bds: <http://www.bigdata.com/rdf/search#>PREFIX actor: <https://resource.swissartresearch.net/actor/>PREFIX Repository: <http://www.metaphacts.com/ontologies/repository#>PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>PREFIX la: <https://linked.art/ns/terms/>PREFIX ldp: <http://www.w3.org/ns/ldp#>PREFIX page: <https://static.swissartresearch.net/page/>PREFIX partial: ...

# %%
print("Total response time is %d seconds" % sum(d['responseTime'] for d in analysis))
# Out:
# Total response time is 43 seconds

# %%
queriesRelatedToFielddefinitions = [d for d in analysis if 'fieldDefinition' in d['query']]

# %%
print("There are %d out of %d queries that do refer to fielddefinitions" % (len(queriesRelatedToFielddefinitions), len(queries)))
# Out:
# There are 0 out of 982 queries that do refer to fielddefinitions

# %%
queriesRelatedToLabelService = [d for d in analysis if '?p0 ?p1' in d['query']]

# %%
print("There are %d out of %d queries that do refer to labels or thumbnails" % (len(queriesRelatedToLabelService), len(queries)))
# Out:
# There are 152 out of 982 queries that do refer to labels or thumbnails

# %%
print(queries[98])
# Out:
# SELECT ?subject ?p0 ?p1 ?p2 ?p3 ?p4 ?p5 WHERE {{{ 	?subject <http://schema.org/thumbnail> ?p0 .  }VALUES (?subject) { (<https://resource.swissartresearch.net/artwork/zbz-990101540730205508>)(<https://resource.swissartresearch.net/artwork/zbz-990107347230205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101531380205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101849710205508>)(<https://resource.swissartresearch.net/artwork/zbz-990107781740205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101844240205508>)(<https://resource.swissartresearch.net/artwork/zbz-990107344720205508>)(<https://resource.swissartresearch.net/artwork/zbz-990102358080205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101840970205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101449840205508>) }}UNION{{ 	?subject <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://platform.swissartresearch.net/search/Object> . 	?subject <http://www.cidoc-crm.org/cidoc-crm/P128_carries> _:_anon_9c5fe820_47fd_4ac9_aff5_544fb31ac8f2 . 	_:_anon_9c5fe820_47fd_4ac9_aff5_544fb31ac8f2 <https://linked.art/ns/terms/digitally_shown_by> _:_anon_bbb327fe_17df_491c_aace_19cc07efc3d1 . 	_:_anon_bbb327fe_17df_491c_aace_19cc07efc3d1 <https://linked.art/ns/terms/digitally_available_via> _:_anon_110982c5_9996_4dcf_a573_ccbab4c70a16 . 	_:_anon_110982c5_9996_4dcf_a573_ccbab4c70a16 <https://linked.art/ns/terms/access_point> ?iiif_image . 	?region <http://www.ics.forth.gr/isl/CRMdig/L49_is_primary_area_of> ?iiif_image . 	?region <http://www.researchspace.org/ontology/boundingBox> ?boundingBox . 	?region <http://www.cidoc-crm.org/cidoc-crm/P2_has_type> <https://resource.swissartresearch.net/type/imageRegion> . 	BIND (STRAFTER(?boundingBox,"xywh=")  AS ?bbox) . 	BIND (CONCAT(STR(?iiif_image) ,"/",?bbox,"/300,/0/default.jpg")  AS ?p1) .  }VALUES (?subject) { (<https://resource.swissartresearch.net/artwork/zbz-990101540730205508>)(<https://resource.swissartresearch.net/artwork/zbz-990107347230205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101531380205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101849710205508>)(<https://resource.swissartresearch.net/artwork/zbz-990107781740205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101844240205508>)(<https://resource.swissartresearch.net/artwork/zbz-990107344720205508>)(<https://resource.swissartresearch.net/artwork/zbz-990102358080205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101840970205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101449840205508>) }}UNION{{ 	?subject <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://platform.swissartresearch.net/search/Object> . 	?subject <http://www.cidoc-crm.org/cidoc-crm/P128_carries> _:_anon_eff25989_0aba_4e47_9723_b2e97146fd26 . 	_:_anon_eff25989_0aba_4e47_9723_b2e97146fd26 <https://linked.art/ns/terms/digitally_shown_by> _:_anon_d0afe065_0f9b_4f41_8e9d_376648483d84 . 	_:_anon_d0afe065_0f9b_4f41_8e9d_376648483d84 <https://linked.art/ns/terms/digitally_available_via> _:_anon_dac1f12b_c7e6_4bba_b943_4ca90fc804d6 . 	_:_anon_dac1f12b_c7e6_4bba_b943_4ca90fc804d6 <https://linked.art/ns/terms/access_point> ?iiif_image . 	BIND (CONCAT(STR(?iiif_image) ,"/pct:12,10,75,75/300,/0/default.jpg")  AS ?p2) .  }VALUES (?subject) { (<https://resource.swissartresearch.net/artwork/zbz-990101540730205508>)(<https://resource.swissartresearch.net/artwork/zbz-990107347230205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101531380205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101849710205508>)(<https://resource.swissartresearch.net/artwork/zbz-990107781740205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101844240205508>)(<https://resource.swissartresearch.net/artwork/zbz-990107344720205508>)(<https://resource.swissartresearch.net/artwork/zbz-990102358080205508>)(<https://resource.swissartresearch.net/artwork/zbz-990101840970205508>)(<https://res ...
